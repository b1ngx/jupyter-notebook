# %%
#https://stackoverflow.com/questions/7470333/remove-certain-attributes-from-html-tags

import lxml.html.clean as clean
import re

code = '''<div id="content">
<div id="allStyleDIV" style="FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; LINE-HEIGHT: 150%">
<div id="allStyleDIV" style="FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; LINE-HEIGHT: 150%">
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">各有关单位</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">：</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><?xml:namespace prefix = "o" /><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 32.25pt; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">根据《高新技术企业认定管理办法》（国科发火〔2016〕32号）和《高新技术企业认定管理工作指引》（国科发火〔2016〕195号）有关规定，</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">现将河南省</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">2017年第一</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">批</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">603</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">家企业</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">拟认定</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">高新技术企业</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">名单（详见附件）予以公示，公示期为10个工作日。</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 32.25pt; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">传真：010-88656259</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"></span> </p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">附件：<a target="_blank" href="3658af4ab651441799877792331912b5/files/1ddf57de06c847b2a637cedd8474ee72.doc">河南省2017年第一批拟认定高新技术企业名单.doc</a></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/28pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 16pt/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal">　　　　　　　　　　　　　　      </span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 16pt/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><p></p></span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; DISPLAY: inline !important; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; DISPLAY: inline !important; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; DISPLAY: inline !important; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; DISPLAY: inline !important; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; DISPLAY: inline !important; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></span><span style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; DISPLAY: inline !important; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></span><span style="WHITE-SPACE: normal; WORD-SPACING: 0px; TEXT-TRANSFORM: none; FLOAT: none; COLOR: rgb(42,42,42); FONT: 21px/32px 仿宋_GB2312; WIDOWS: 1; DISPLAY: inline !important; LETTER-SPACING: normal; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px"></span> 
<p style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px"></p>
<p style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></p>
<p style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></p>
<p style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></p>
<p style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/32px 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/22pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">              <span class="Apple-converted-space" style="BORDER-TOP-STYLE: none; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">     <span class="Apple-converted-space" style="BORDER-TOP-STYLE: none; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">  </span></span></span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">全国高新技术企业认定管理工作领导小组办公室</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; PADDING-TOP: 0px; FONT: 21px/22pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">                       <span class="Apple-converted-space" style="BORDER-TOP-STYLE: none; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">    <span class="Apple-converted-space" style="BORDER-TOP-STYLE: none; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">  </span></span></span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">（科技部火炬中心代章）</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; TEXT-ALIGN: left; PADDING-TOP: 0px; FONT: 21px/22pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 30pt; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">                             2017</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">年8</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">月29</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">日</span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px"><p></p></span></p>
<p class="p0" style="BORDER-TOP-STYLE: none; WHITE-SPACE: normal; WORD-SPACING: 0px; BORDER-BOTTOM-STYLE: none; TEXT-TRANSFORM: none; COLOR: rgb(42,42,42); PADDING-BOTTOM: 0px; TEXT-ALIGN: left; PADDING-TOP: 0px; FONT: 21px/22pt 仿宋_GB2312; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0pt 0px; WIDOWS: 1; BORDER-LEFT-STYLE: none; LETTER-SPACING: normal; PADDING-RIGHT: 0px; BACKGROUND-COLOR: rgb(255,255,255); TEXT-INDENT: 0px; -webkit-text-stroke-width: 0px; font-stretch: normal"><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">    </span><span style="BORDER-TOP-STYLE: none; FONT-SIZE: 16pt; FONT-FAMILY: 仿宋_GB2312; BORDER-BOTTOM-STYLE: none; PADDING-BOTTOM: 0px; PADDING-TOP: 0px; BORDER-RIGHT-STYLE: none; PADDING-LEFT: 0px; MARGIN: 0px; BORDER-LEFT-STYLE: none; PADDING-RIGHT: 0px">（此件主动公开）</span></p></div></div>
<div class="fujian">
</div>
</div>'''

#safe_attrs = clean.defs.safe_attrs
cleaner = clean.Cleaner(safe_attrs_only=True, safe_attrs=frozenset())
cleansed = cleaner.clean_html(code)
whitespace_re = re.compile("\s+")


print(whitespace_re.sub('', cleansed))
# Out:
# frozenset({'datetime', 'usemap', 'method', 'value', 'name', 'clear', 'disabled', 'size', 'height', 'align', 'longdesc', 'src', 'id', 'rows', 'width', 'hspace', 'dir', 'action', 'border', 'maxlength', 'charoff', 'valign', 'tabindex', 'href', 'cite', 'alt', 'label', 'cols', 'checked', 'accept-charset', 'ismap', 'class', 'rules', 'start', 'shape', 'prompt', 'compact', 'coords', 'vspace', 'axis', 'cellspacing', 'charset', 'media', 'noshade', 'rel', 'target', 'colspan', 'rev', 'abbr', 'color', 'scope', 'title', 'type', 'headers', 'multiple', 'char', 'accesskey', 'for', 'nowrap', 'cellpadding', 'frame', 'rowspan', 'hreflang', 'lang', 'nohref', 'readonly', 'summary', 'accept', 'selected', 'span', 'enctype'})
# ...

# %%
import re

print(re.match(r'<.*?>', '<div id="content"></div>').group())
print(re.match(r'<[^>]*>', '<div id="content"></div>').group())
# Out:
# <div id="content">
# <div id="content">
